# %% [markdown]
# <a href="https://colab.research.google.com/github/naomibuah/Unit_2_Python/blob/main/Copy_of_Project_3_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#This is the dataset we are analyzing
covid_df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
covid_df

#covid_df_call is to filter out the state and county of California
covid_df_cali = covid_df[(covid_df['state'] == 'California') & (covid_df['county'] == 'Los Angeles')]
covid_df_cali

#This to only look at the dates from the last 30 days starting on 1-15-20
covid_df_cali = covid_df_cali[(covid_df['date'] <= '2021-01-15') & (covid_df_cali['date'] >= '2020-12-15')]

#This is to filter out cases and deaths in addition to state,county, and date and to remove the fips column
covid_df_cali[['state','county','cases','deaths','date']]
covid_df_cali.drop('fips', axis ='columns', inplace = True)

#This is to examine New York's covid cases and it is also filtered by state, county, date, deaths, and cases
covid_df_NY = covid_df[['state','county','cases','deaths','date']]
covid_df_NY = covid_df_NY[(covid_df_NY['state'] == 'New York') & (covid_df_NY['county'] =='New York City')]

covid_df_NY = covid_df_NY[(covid_df_NY['date'] <= '2021-01-15') & (covid_df_NY['date'] >='2020-12-15')]
covid_df_NY

#Here is a visualization of how many deaths occured due to covid in both states . It is safe to say that when compared New York City had a higher peak of deaths compared to Los Angeles.
#New Yorks peak hovers around 24,600 deaths in the last 30 days while Los Angeles hovers around 9,000 in total.
sns.displot(covid_df_NY['deaths'])
sns.displot(covid_df_cali['deaths'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]

# %%
covid_df_cali
#Thsi is all of the covid cases that occured from December 15 to January 1 in Los Angeles, California
# Out:
#               date       county       state   cases   deaths
# 829852  2020-12-15  Los Angeles  California  543949   8431.0
# 833099  2020-12-16  Los Angeles  California  566185   8568.0
# 836345  2020-12-17  Los Angeles  California  580505   8664.0
# 839590  2020-12-18  Los Angeles  California  596910   8757.0
# 842835  2020-12-19  Los Angeles  California  610562   8817.0
# 846081  2020-12-20  Los Angeles  California  623875   8875.0
# 849326  2020-12-21  Los Angeles  California  635058   8931.0
# 852571  2020-12-22  Los Angeles  California  647766   9016.0
# 855816  2020-12-23  Los Angeles  California  664193   9153.0
# 859061  2020-12-24  Los Angeles  California  677538   9299.0
# 862306  2020-12-25  Los Angeles  California  677538   9299.0
# 865551  2020-12-26  Los Angeles  California  706712   9438.0
# 868796  2020-12-27  Los Angeles  California  720099   9482.0
# 872041  2020-12-28  Los Angeles  California  733612   9555.0
# 875286  2020-12-29  Los Angeles  California  746381   9782.0
# 878531  2020-12-30  Los Angeles  California  756412  10056.0
# 881776  2020-12-31  Los Angeles  California  770915  10345.0
# 885021  2021-01-01  Los Angeles  California  790895  10552.0
# 888266  2021-01-02  Los Angeles  California  806523  10682.0
# 891513  2021-01-03  Los Angeles  California  818959  10773.0
# 894760  2021-01-04  Los Angeles  California  827843  10850.0
# 898005  2021-01-05  Los Angeles  California  840956  11071.0
